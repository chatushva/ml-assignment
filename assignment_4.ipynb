# %% [markdown]
# <a href="https://colab.research.google.com/github/chatushva/ml-assignment/blob/main/assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('/content/ozone.csv')

# %%
data.head()
# Out:
#    Month  Day_of_month  Day_of_week  ozone_reading  pressure_height  \
# 0      1             5            1           5.34             5760
# 1      1             6            2           5.77             5720
# 2      1             7            3           3.69             5790
# 3      1             8            4           3.89             5790
# 4      1             9            5           5.76             5700
#
#    Wind_speed  Humidity  Temperature_Sandburg  Temperature_ElMonte  \
# 0           3        51                    54                45.32
# 1           4        69                    35                49.64
# 2           6        19                    45                46.40
# 3           3        25                    55                52.70
# 4           3        73                    41                48.02
#
#    Inversion_base_height  Pressure_gradient  Inversion_temperature  Visibility
# ...

# %%
data.tail()
# Out:
#      Month  Day_of_month  Day_of_week  ozone_reading  pressure_height  \
# 198     12            23            4           3.21             5680
# 199     12            27            1           1.74             5730
# 200     12            28            2           2.69             5690
# 201     12            29            3           5.05             5650
# 202     12            30            4           0.72             5550
#
#      Wind_speed  Humidity  Temperature_Sandburg  Temperature_ElMonte  \
# 198           4        57                    47                45.32
# 199           3        53                    51                49.28
# 200           3        23                    51                49.28
# 201           3        61                    50                46.58
# 202           4        85                    39                41.00
#
#      Inversion_base_height  Pressure_gradient  Inversion_temperature  \
# ...

# %%
data.sample()
# Out:
#     Month  Day_of_month  Day_of_week  ozone_reading  pressure_height  \
# 29      2            23            1           4.04             5690
#
#     Wind_speed  Humidity  Temperature_Sandburg  Temperature_ElMonte  \
# 29           7        19                    53                50.18
#
#     Inversion_base_height  Pressure_gradient  Inversion_temperature  \
# 29                   5000                  7                   49.1
#
#     Visibility
# 29         300

# %%
data['Humidity']
# Out:
# 0      51
# 1      69
# 2      19
# 3      25
# 4      73
#        ..
# 198    57
# 199    53
# 200    23
# 201    61
# 202    85
# Name: Humidity, Length: 203, dtype: int64

# %%
data.columns
# Out:
# Index(['Month', 'Day_of_month', 'Day_of_week', 'ozone_reading',
#        'pressure_height', 'Wind_speed', 'Humidity', 'Temperature_Sandburg',
#        'Temperature_ElMonte', 'Inversion_base_height', 'Pressure_gradient',
#        'Inversion_temperature', 'Visibility'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Month                    0
# Day_of_month             0
# Day_of_week              0
# ozone_reading            0
# pressure_height          0
# Wind_speed               0
# Humidity                 0
# Temperature_Sandburg     0
# Temperature_ElMonte      0
# Inversion_base_height    0
# Pressure_gradient        0
# Inversion_temperature    0
# Visibility               0
# dtype: int64

# %%
corelation=data.corr()

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)
# Out:
# <Axes: >

# %%
sns.relplot(x='ozone_reading',y='pressure_height',data=data)

# %%
sns.displot(data['ozone_reading'])
